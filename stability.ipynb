# %% [markdown]
# # Analyse de la stabilité

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import adjusted_rand_score
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans

# %% [markdown]
# # Data

# %%
data = pd.read_csv('data_scaled.csv')

# %%
# Afficher un histogramme de la colonne 'recency'
plt.hist(data['recency_unscaled'], bins=360, edgecolor='black')
plt.title('Distribution de la colonne "recency"')
plt.xlabel('Recency')
plt.ylabel('Fréquence')
plt.show()

# %%
data['recency_unscaled'].describe()
# Out:
# count    103677.000000
# mean       -291.551935
# std         154.010981
# min        -772.000000
# 25%        -403.000000
# 50%        -273.000000
# 75%        -167.000000
# max           0.000000
# Name: recency_unscaled, dtype: float64
